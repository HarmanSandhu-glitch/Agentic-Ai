# %%
# agent.invoke({"messages": [{"role": "user", "content": "How is the weather today in Berlin?"}]})
ModelService.ListModels
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3234, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3233 try:
# -> 3234     response: GenerateContentResponse = self.client.models.generate_content(
#    3235         **request,
#    3236     )
#    3237 except ClientError as e:
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/models.py:6465, in Models.generate_content(self, model, contents, config)
#    6458     logger.warning(
#    6459         'Tools at indices [%s] are not compatible with automatic function '
#    6460         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   6463         indices_str,
#    6464     )
# -> 6465   return self._generate_content(
#    6466       model=model, contents=contents, config=parsed_config
#    6467   )
#    6469 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    6470     parsed_config
#    6471 )
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/models.py:4916, in Models._generate_content(self, model, contents, config)
#    4914 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4916 response = self._api_client.request(
#    4917     'post', path, request_dict, http_options
#    4918 )
#    4920 if config is not None and getattr(
#    4921     config, 'should_return_http_response', None
#    4922 ):
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1618, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1615 http_request = self._build_request(
#    1616     http_method, path, request_dict, http_options
#    1617 )
# -> 1618 response = self._request(http_request, http_options, stream=False)
#    1619 response_body = (
#    1620     response.response_stream[0] if response.response_stream else ''
#    1621 )
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1409, in BaseApiClient._request(self, http_request, http_options, stream)
#    1408     retry = tenacity.Retrying(**retry_kwargs)
# -> 1409     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1411 return self._retry(self._request_once, http_request, stream)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.11-linux-x86_64-gnu/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1388, in BaseApiClient._request_once(self, http_request, stream)
#    1387   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1388 errors.APIError.raise_for_response(response)
#    1389 return HttpResponse(
#    1390     response.headers, response if stream else [response.text]
#    1391 )
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/google/genai/errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 agent.invoke({"messages": [{"role": "user", "content": "How is the weather today in Berlin?"}]})
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3934         ),
#    3935         print_mode=print_mode,
#    3936         output_keys=output_keys,
#    3937         interrupt_before=interrupt_before,
#    3938         interrupt_after=interrupt_after,
#    3939         durability=durability,
#    3940         control=control,
#    3941         **kwargs,
#    3942     ):
#    3943         if stream_mode == "values":
#    3944             if len(chunk) == 2:
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2982, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2980 for task in loop.match_cached_writes():
#    2981     loop.output_writes(task.id, task.writes, cached=True)
# -> 2982 for _ in runner.tick(
#    2983     [t for t in loop.tasks.values() if not t.writes],
#    2984     timeout=self.step_timeout,
#    2985     get_waiter=get_waiter,
#    2986     schedule_task=loop.accept_push,
#    2987 ):
#    2988     # emit output
#    2989     yield from _output(
#    2990         stream_mode,
#    2991         print_mode,
#    (...)   2997         _state_mapper,
#    2998     )
#    2999 loop.after_tick()
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain/agents/factory.py:1421, in create_agent.<locals>.model_node(state, runtime)
#    1409 request = ModelRequest(
#    1410     model=model,
#    1411     tools=default_tools,
#    (...)   1417     runtime=runtime,
#    1418 )
#    1420 if wrap_model_call_handler is None:
# -> 1421     model_response = _execute_model_sync(request)
#    1422     return _build_commands(model_response)
#    1424 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain/agents/factory.py:1393, in create_agent.<locals>._execute_model_sync(request)
#    1390 if request.system_message:
#    1391     messages = [request.system_message, *messages]
# -> 1393 output = model_.invoke(messages)
#    1394 if name:
#    1395     output.name = name
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:2701, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2698         msg = "Tools are already defined.code_execution tool can't be defined"
#    2699         raise ValueError(msg)
# -> 2701 return super().invoke(input, config, stop=stop, **kwargs)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:3238, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3234     response: GenerateContentResponse = self.client.models.generate_content(
#    3235         **request,
#    3236     )
#    3237 except ClientError as e:
# -> 3238     _handle_client_error(e, request)
#    3240 return _response_to_result(response)
#
# File /run/media/harmn/Gnrl/Agentic Ai/.venv/lib/python3.12/site-packages/langchain_google_genai/chat_models.py:169, in _handle_client_error(e, request)
#     167 model_name = request.get("model", "unknown")
#     168 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 169 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-1.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ModelService.ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}
# During task with name 'model' and id '834bd9ef-6279-81bc-9fc1-0e184639af70'

# %%
from langchain_core import tools
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

def get_weather(city: str) -> str:
    """Function that returns weather"""
    return f"It's sunny in {city}"

# 1. Initialize the Gemini LLM
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")

# 2. Create the agent
agent = create_agent(
    model=llm, # Pass the model instance
    tools=[get_weather],
    system_prompt="Nothing yet..."
)
agent
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# Langchain version v1
